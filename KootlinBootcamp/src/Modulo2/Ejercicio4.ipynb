// %%
fun main() {
    // Lista con dos elementos nulos (forma 1)
    val list1: List<String?> = listOf(null, null)

    // Lista con dos elementos nulos (forma 2)
    val list2 = listOf<String?>(null, null)

    // Lista que puede ser nula
    val list3: List<String>? = null

    println("List1: $list1")
    println("List2: $list2")
    println("List3: $list3")
}

main()
// Out:
// List1: [null, null]
// List2: [null, null]
// List3: null
