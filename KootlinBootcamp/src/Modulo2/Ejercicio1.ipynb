// %%
fun dameFish() {
    val fish = 2.plus(71).plus(233).minus(13)
    val aquariums = fish.div(30)
    println("Total fish: $fish")
    println("Aquariums needed: $aquariums")
}

dameFish()
// Out:
// Total fish: 293
// Aquariums needed: 9
