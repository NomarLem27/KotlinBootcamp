// %%
fun main() {
    var rainbowColor = "Red"
    println("Rainbow color: $rainbowColor")

    rainbowColor = "Blue"
    println("Changed rainbow color: $rainbowColor")

    val blackColor = "Black"
    println("Black color: $blackColor")


}

main()
// Out:
// Rainbow color: Red
// Changed rainbow color: Blue
// Black color: Black
