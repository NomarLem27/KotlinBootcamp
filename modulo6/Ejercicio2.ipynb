// %%
fun List<Int>.divisibleByThree(): List<Int> {
    return this.filter { it % 3 == 0 }
}

fun main() {
    val numbers = listOf(1, 2, 3, 4, 5, 6, 7, 8, 9, 0)
    println(numbers.divisibleByThree())
}
